# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import credentials
import requests
import datetime as dt
#pulling data API
key =credentials.login['key_isaham']  # extract password

# %%
def sector_filter(sector):

  # pulling data from api
  URL = 'https://admin.isaham.my/api/stocks/list'
  r = requests.get(url = URL) 
  data = r.json() 
  df = pd.DataFrame(data['stocks'],columns = ['code','symbol','name','primary-sector','secondary-sector'])

  wl = df[df["primary-sector"]==sector]
  wl = list(wl.symbol)

  return(wl)

# %%
def strategy_plan(wl,start_year):
    wp_acc=[]
    wp_only=[]
    total_trade=[]
    wr = []
    ori_data = {}
    
    for m,stock in enumerate (wl):
        #print("----------------PROCESSING {}------------------".format(stock))
        #symbol = "UNISEM"  # which stock to pull
        symbol = stock    

        response = requests.get("https://admin.isaham.my/api/chart?stock={}&key={}".format(symbol,key))
        data = response.json()
        
        if data['status'] != 'Stock not found.':
            ori = pd.DataFrame.from_dict(data)
            ori = ori[['c','d','h','l','o','v']]
            
            if sum(ori["v"].tail(5))> 1:
                ori['d'] = pd.to_datetime(ori['d'], dayfirst= True )
                # adding the stock names
                ori["Stock"] = stock
                ori_data[f"{symbol}"] = ori
                #all_ori_stocks.append(ori_data[stock])

                df = ori.reset_index(drop=False)
                #print(data)

                #Tuning OB and OS level
                ob_cross=85
                os_cross=35


                #identify MA50
                n=50
                ma50=[] 

                for i in range(len(df["c"])-(n-1)):
                    ma = round(sum(df["c"][i:i+(n)])/n,4)
                    #print(ma)
                    ma50.append(ma)

                df["MA50"] = pd.Series(ma50)
                df["MA50"] = df["MA50"].shift(n-1)

                #filter uptrend price above ma50
                # Calculating the gap of both MA
                df["MAgap"] = df["c"] -  df["MA50"] 

                df.set_index('d',inplace=True,drop=True)
                df.index.name = None

                #create signal for uptrend price above ma50 
                #result not accurate for stochastic when just filter uptrend only
                df["Uptrend"]=df['MAgap']>0
                Uptrend=df["Uptrend"]
                Uptrend_signal=Uptrend[Uptrend==True]
                #signal stochastic
                #Create the "L14" column in the DataFrame
                df['L14'] = df['l'].rolling(window=14).min()

                #Create the "H14" column in the DataFrame
                df['H14'] = df['h'].rolling(window=14).max()

                #Create the "%K" column in the DataFrame
                df['%K'] = 100*((df['c'] - df['L14']) / (df['H14'] - df['L14']) )

                #Create the "%D" column in the DataFrame
                df['%D'] = df['%K'].rolling(window=3).mean()

                #Create a column in the DataFrame showing "TRUE" if buy entry signal is given and "FALSE" otherwise. 
                #A buy is initiated when the %K line crosses up through the %D line and the value of the oscillator is below 20 
                df['Buy OS'] = ((df['%K'] > df['%D']) & (df['%K'].shift(1) < df['%D'].shift(1))) & (df['%D'] < os_cross) & (Uptrend_signal)

                #Create a column in the DataFrame showing "TRUE" if sell entry signal is given and "FALSE" otherwise. 
                #A sell is initiated when the %K line crosses down through the %D line and the value of the oscillator is above 80 
                df['Sell OB'] = ((df['%K'] < df['%D']) & (df['%K'].shift(1) > df['%D'].shift(1))) & (df['%D'] > ob_cross) 

                overbought =df['Sell OB']
                oversold =df['Buy OS']
                date_os=list(oversold[oversold == True].index)
                date_ob=list(overbought[overbought == True].index)

                # transaction recording for stochastic trading plan
                buy = []
                sell = []
                sdate = []
                bdate = []
                wr = []
                pct = []
                stock_name=[]
                for n,i in enumerate(date_os):

                    #print(n,"Buy:", i, "Price:", df['c'].loc[i])
                    buy.append(df['c'].loc[i])
                    bdate.append(i)
                    r=[]
                    #print("before", len(r))
                    for m,k in enumerate(date_ob):

                        if k>i:
                            r.append(m)
                            #print('after',len(r))
                            if len(r) ==1:
                                #print(m,"Sell :", k, "Price:",df['c'].loc[k])
                                #print("Percentage change:",(((df['c'].loc[k]/df['c'].loc[i])-1)*100) )
                                sell.append(df['c'].loc[k])
                                sdate.append(k)
                                pct_change=((df['c'].loc[k]/df['c'].loc[i])-1)*100
                                pct.append(((df['c'].loc[k]/df['c'].loc[i])-1)*100)
                                stock_name.append(symbol)

                            elif len(r)>1:
                                pass
                diff =len(buy)-len(sell)
                # Checking for final transaction, make sure it is sell, as we want to close the position
                if len(buy) == len(sell):
                    #print("Yes \n", "Buy:", len(buy), "Sell:", len(sell))
                    #print("Position closed")
                    pass

                elif len(buy) != len(sell):
                    #print("No, \n", "Buy:{}, Sell:{}, Closing the position".format(len(buy),len(sell)))
                    del(buy[-diff:])
                    del(bdate[-diff:])
                    #print("Position closed")
                dct = {
                "Buy_Date": bdate,
                "Buy": buy,
                "Sell": sell,
                "Sell_Date": sdate,
                "Pct_change": pct,
                'Name_stock':stock_name }   
                trans = pd.DataFrame(dct)
                #print(trans)

                if trans.shape[0] > 0:
                    # Define variable for winning rate
                    
                    #wp_acc=[]
                    #wp_only=[]
                    #total_trade=[]
                    #wr = []
                    
                    for i in range(len(trans)):
                        if trans["Pct_change"][i] > 0:
                            wr.append(1)
                        else:
                            wr.append(0)
                         
                    trans["wr"] = pd.Series(wr)

                    trans.set_index('Buy_Date', inplace=True)
                    #print(trans)

                    #set date for period of backtest
                    #trans=trans['01-01-2020':]        
                    year=start_year
                    date1 = "01-01-{}".format(start_year)  
                    date2 = "01-01-{}".format(start_year+1)  
                    #date3 =
                    trans=trans[date1:date2]
                    #print(trans)

                    win_only=trans[trans["wr"]==1]
                    #print(win_only)
                    net_pct_win=round(sum(win_only['Pct_change']),4)
                    wp_only.append(net_pct_win)
                    #print(net_pct_win)

                    #calculate net percentage
                    net_pct=round(sum(trans['Pct_change']),4)
                    wp_acc.append(net_pct)

                    #calculate number of trade record
                    num_trade=len(trans['wr'])
                    total_trade.append(num_trade)
                # if no buy signal history, just skip the stock    
                else:
                    pass
            # if sum of 5day vol > 0, then assume it still listed
            else:
                pass

        # If data.status == data['status'] != 'Stock not found.'
        else:
            pass
                

        #print('Stock :{}'.format(symbol))
        #print('When Overbought cross>{}.'.format(ob_cross))
        #print('When Oversold cross<{}.'.format(os_cross))
        #print("Winning rate at {}% for {} trades .".format(net_pct, len(trans["wr"])))
        #print("----------------DONE {}------------------".format(symbol)) 
    #print('######################### DONE DATA PREP ###########################')
    return(wp_acc,wp_only,total_trade,year)

# %%
def average_wr(wp_acc,wp_only,total_trade,year):

    avg_2 = round(sum(wp_acc)/len(wp_acc),4)
    total_win =round(sum(wp_only)/len(wp_only),4)
    total_num_trade =sum(total_trade)
    print("Overall Winning Rate in {} : {}%".format(year,avg_2))
    print('Total number of trade : {}'.format(total_num_trade))
    print("Average Winning Rate for win only : {}%".format(total_win)) 
    #print("############################## Finish #################################")
    return avg_2

# %%
def winning_rate(wl,start_year):
    
    wp_acc,wp_only,total_trade,year=strategy_plan(wl,start_year)
    avg_2=average_wr(wp_acc,wp_only,total_trade,year)
    #wp_acc,wp_only,total_trade=label_column(trans,symbo)
    
    return wp_acc,wp_only,total_trade,avg_2,year

# %% [markdown]
# ### By sector performance

# %%
sectors=['Healthcare',
         'Telecommunications & Media',
         'Technology',
         'Utilities',
        'Energy',
        'Construction',
         'Consumer Products & Services',
         'Industrial Products & Services',
         'Property',
         'Transportation & Logistics',
         'Finance Services',
         'Plantation'
]

save_16=[]
name_sector_16=[]
year_16=[]

save_17=[]
name_sector_17=[]
year_17=[]

save_18=[]
name_sector_18=[]
year_18=[]

save_19=[]
name_sector_19=[]
year_19=[]

save_20=[]
name_sector_20=[]
year_20=[]

for sector in sectors:
    wl = sector_filter(sector)
    print(f"{sector}:")
    
    print('2016')
    wp_acc,wp_only,total_trade,avg_2,year= winning_rate(wl,start_year=2016)
    save_16.append(avg_2)
    name_sector_16.append(sector)
    year_16.append(year)
    #print('############################## DONE #################################') 
    
    print(year+1)
    wp_acc,wp_only,total_trade,avg_2,year= winning_rate(wl,start_year=2017)
    save_17.append(avg_2)
    name_sector_17.append(sector)
    year_17.append(year)
    #print('############################## DONE #################################')  
    
    print(year+1)
    wp_acc,wp_only,total_trade,avg_2,year= winning_rate(wl,start_year=2018)
    save_18.append(avg_2)
    name_sector_18.append(sector)
    year_18.append(year)
    #print('############################## DONE #################################') 
    
    print(year+1)
    wp_acc,wp_only,total_trade,avg_2,year= winning_rate(wl,start_year=2019)
    save_19.append(avg_2)
    name_sector_19.append(sector)
    year_19.append(year)
    #print('############################## DONE #################################')  
    
    print(year+1)
    wp_acc,wp_only,total_trade,avg_2,year= winning_rate(wl,start_year=2020)
    save_20.append(avg_2)
    name_sector_20.append(sector)
    year_20.append(year)
    print('############################## DONE #################################') 

totalresult = save_16 + save_17 + save_18 +save_19 + save_20 
allsector = name_sector_16 + name_sector_17 + name_sector_18+name_sector_19 + name_sector_20 
record_y = year_16 + year_17 + year_18 + year_19 + year_20 


backtest= {
    "Sector": allsector,
    "Winning_Rate": totalresult,
    'Year': record_y
}  

# Save document for stochastic strategy
df_winning_rate = pd.DataFrame(backtest)
# Out:
# Healthcare:
# 2016
# Overall Winning Rate in 2016 : 12.742%
# Total number of trade : 68
# Average Winning Rate for win only : 26.5223%
# 2017
# Overall Winning Rate in 2017 : 44.5969%
# Total number of trade : 79
# Average Winning Rate for win only : 59.5484%
# 2018
# Overall Winning Rate in 2018 : -32.413%
# Total number of trade : 82
# Average Winning Rate for win only : 11.5%
# 2019
# Overall Winning Rate in 2019 : 15.1658%
# Total number of trade : 91
# Average Winning Rate for win only : 44.9576%
# 2020
# Overall Winning Rate in 2020 : 100.4283%
# Total number of trade : 95
# Average Winning Rate for win only : 125.2099%
# ############################## DONE #################################
# Telecommunications & Media:
# 2016
# Overall Winning Rate in 2016 : 0.4884%
# Total number of trade : 121
# Average Winning Rate for win only : 17.2365%
# 2017
# Overall Winning Rate in 2017 : 22.8049%
# Total number of trade : 183
# Average Winning Rate for win only : 63.3653%
# 2018
# Overall Winning Rate in 2018 : -26.4375%
# Total number of trade : 91
# Average Winning Rate for win only : 10.6529%
# 2019
# Overall Winning Rate in 2019 : -1.0917%
# Total number of trade : 157
# Average Winning Rate for win only : 28.8934%
# 2020
# Overall Winning Rate in 2020 : 114.1105%
# Total number of trade : 165
# Average Winning Rate for win only : 137.5073%
# ############################## DONE #################################
# Technology:
# 2016
# Overall Winning Rate in 2016 : 13.9013%
# Total number of trade : 424
# Average Winning Rate for win only : 46.8809%
# 2017
# Overall Winning Rate in 2017 : 18.4619%
# Total number of trade : 554
# Average Winning Rate for win only : 72.6074%
# 2018
# Overall Winning Rate in 2018 : -26.8277%
# Total number of trade : 353
# Average Winning Rate for win only : 23.939%
# 2019
# Overall Winning Rate in 2019 : -14.0959%
# Total number of trade : 541
# Average Winning Rate for win only : 46.1962%
# 2020
# Overall Winning Rate in 2020 : 169.2363%
# Total number of trade : 572
# Average Winning Rate for win only : 205.111%
# ############################## DONE #################################
# Utilities:
# 2016
# Overall Winning Rate in 2016 : -3.7452%
# Total number of trade : 75
# Average Winning Rate for win only : 14.3949%
# 2017
# Overall Winning Rate in 2017 : 9.3071%
# Total number of trade : 54
# Average Winning Rate for win only : 26.1375%
# 2018
# Overall Winning Rate in 2018 : -10.6202%
# Total number of trade : 59
# Average Winning Rate for win only : 17.7834%
# 2019
# Overall Winning Rate in 2019 : 40.575%
# Total number of trade : 59
# Average Winning Rate for win only : 46.6092%
# 2020
# Overall Winning Rate in 2020 : 39.8938%
# Total number of trade : 80
# Average Winning Rate for win only : 65.8557%
# ############################## DONE #################################
# Energy:
# 2016
# Overall Winning Rate in 2016 : -10.0023%
# Total number of trade : 118
# Average Winning Rate for win only : 21.4241%
# 2017
# Overall Winning Rate in 2017 : 18.7703%
# Total number of trade : 200
# Average Winning Rate for win only : 60.228%
# 2018
# Overall Winning Rate in 2018 : -32.0337%
# Total number of trade : 114
# Average Winning Rate for win only : 25.2678%
# 2019
# Overall Winning Rate in 2019 : 37.8375%
# Total number of trade : 227
# Average Winning Rate for win only : 113.0608%
# 2020
# Overall Winning Rate in 2020 : -31.603%
# Total number of trade : 152
# Average Winning Rate for win only : 29.5345%
# ############################## DONE #################################
# Construction:
# 2016
# Overall Winning Rate in 2016 : 7.3314%
# Total number of trade : 320
# Average Winning Rate for win only : 29.5998%
# 2017
# Overall Winning Rate in 2017 : 0.4162%
# Total number of trade : 301
# Average Winning Rate for win only : 37.6174%
# 2018
# Overall Winning Rate in 2018 : -32.8794%
# Total number of trade : 150
# Average Winning Rate for win only : 4.8813%
# 2019
# Overall Winning Rate in 2019 : -28.1339%
# Total number of trade : 287
# Average Winning Rate for win only : 24.6168%
# 2020
# Overall Winning Rate in 2020 : 27.694%
# Total number of trade : 301
# Average Winning Rate for win only : 59.0702%
# ############################## DONE #################################
# Consumer Products & Services:
# 2016
# Overall Winning Rate in 2016 : 5.6355%
# Total number of trade : 861
# Average Winning Rate for win only : 24.8713%
# 2017
# Overall Winning Rate in 2017 : 6.5125%
# Total number of trade : 1016
# Average Winning Rate for win only : 40.9254%
# 2018
# Overall Winning Rate in 2018 : -19.9317%
# Total number of trade : 637
# Average Winning Rate for win only : 12.0169%
# 2019
# Overall Winning Rate in 2019 : -14.538%
# Total number of trade : 867
# Average Winning Rate for win only : 23.1232%
# 2020
# Overall Winning Rate in 2020 : 107.3162%
# Total number of trade : 992
# Average Winning Rate for win only : 124.8543%
# ############################## DONE #################################
# Industrial Products & Services:
# 2016
# Overall Winning Rate in 2016 : 2.1862%
# Total number of trade : 1084
# Average Winning Rate for win only : 20.9043%
# 2017
# Overall Winning Rate in 2017 : 4.8228%
# Total number of trade : 1303
# Average Winning Rate for win only : 38.8083%
# 2018
# Overall Winning Rate in 2018 : -17.3715%
# Total number of trade : 699
# Average Winning Rate for win only : 9.1891%
# 2019
# Overall Winning Rate in 2019 : -1.6534%
# Total number of trade : 1087
# Average Winning Rate for win only : 33.3695%
# 2020
# Overall Winning Rate in 2020 : 87.8026%
# Total number of trade : 1426
# Average Winning Rate for win only : 115.3032%
# ############################## DONE #################################
# Property:
# 2016
# Overall Winning Rate in 2016 : 4.3188%
# Total number of trade : 431
# Average Winning Rate for win only : 20.2237%
# 2017
# Overall Winning Rate in 2017 : -7.1927%
# Total number of trade : 538
# Average Winning Rate for win only : 37.1631%
# 2018
# Overall Winning Rate in 2018 : -27.1838%
# Total number of trade : 279
# Average Winning Rate for win only : 4.8798%
# 2019
# Overall Winning Rate in 2019 : -27.1166%
# Total number of trade : 450
# Average Winning Rate for win only : 16.3164%
# 2020
# Overall Winning Rate in 2020 : 27.7619%
# Total number of trade : 496
# Average Winning Rate for win only : 56.274%
# ############################## DONE #################################
# Transportation & Logistics:
# 2016
# Overall Winning Rate in 2016 : -13.3494%
# Total number of trade : 166
# Average Winning Rate for win only : 24.3607%
# 2017
# Overall Winning Rate in 2017 : -20.4317%
# Total number of trade : 185
# Average Winning Rate for win only : 24.4759%
# 2018
# Overall Winning Rate in 2018 : -14.6197%
# Total number of trade : 89
# Average Winning Rate for win only : 12.8508%
# 2019
# Overall Winning Rate in 2019 : -26.8603%
# Total number of trade : 198
# Average Winning Rate for win only : 20.5929%
# 2020
# Overall Winning Rate in 2020 : 193.3906%
# Total number of trade : 187
# Average Winning Rate for win only : 219.0602%
# ############################## DONE #################################
# Finance Services:
# 2016
# Overall Winning Rate in 2016 : 14.774%
# Total number of trade : 142
# Average Winning Rate for win only : 21.5656%
# 2017
# Overall Winning Rate in 2017 : 18.809%
# Total number of trade : 173
# Average Winning Rate for win only : 35.2134%
# 2018
# Overall Winning Rate in 2018 : 0.1342%
# Total number of trade : 104
# Average Winning Rate for win only : 8.2606%
# 2019
# Overall Winning Rate in 2019 : -22.1653%
# Total number of trade : 120
# Average Winning Rate for win only : 11.1975%
# 2020
# Overall Winning Rate in 2020 : 30.7502%
# Total number of trade : 133
# Average Winning Rate for win only : 40.8568%
# ############################## DONE #################################
# Plantation:
# 2016
# Overall Winning Rate in 2016 : -1.011%
# Total number of trade : 212
# Average Winning Rate for win only : 11.408%
# 2017
# Overall Winning Rate in 2017 : 0.7177%
# Total number of trade : 197
# Average Winning Rate for win only : 13.0829%
# 2018
# Overall Winning Rate in 2018 : -15.8866%
# Total number of trade : 133
# Average Winning Rate for win only : 5.8308%
# 2019
# Overall Winning Rate in 2019 : -11.3974%
# Total number of trade : 173
# Average Winning Rate for win only : 9.4051%
# 2020
# Overall Winning Rate in 2020 : 43.7428%
# Total number of trade : 314
# Average Winning Rate for win only : 68.8933%
# ############################## DONE #################################

# %%
df_winning_rate.to_csv (r'C:\Users\Mo Syamil\Documents\stochastic function\Winning rate function.csv', index = False, header=True)

# %%
df_winning_rate
# Out:
#                             Sector  Winning_Rate  Year
# 0                       Healthcare       12.7420  2016
# 1       Telecommunications & Media        0.4884  2016
# 2                       Technology       13.9013  2016
# 3                        Utilities       -3.7452  2016
# 4                           Energy      -10.0023  2016
# 5                     Construction        7.3314  2016
# 6     Consumer Products & Services        5.6355  2016
# 7   Industrial Products & Services        2.1862  2016
# 8                         Property        4.3188  2016
# 9       Transportation & Logistics      -13.3494  2016
# 10                Finance Services       14.7740  2016
# 11                      Plantation       -1.0110  2016
# 12                      Healthcare       44.5969  2017
# 13      Telecommunications & Media       22.8049  2017
# 14                      Technology       18.4619  2017
# 15                       Utilities        9.3071  2017
# 16                          Energy       18.7703  2017
# 17                    Construction        0.4162  2017
# 18    Consumer Products & Services        6.5125  2017
# 19  Industrial Products & Services        4.8228  2017
# 20                        Property       -7.1927  2017
# 21      Transportation & Logistics      -20.4317  2017
# 22                Finance Services       18.8090  2017
# 23                      Plantation        0.7177  2017
# 24                      Healthcare      -32.4130  2018
# 25      Telecommunications & Media      -26.4375  2018
# 26                      Technology      -26.8277  2018
# 27                       Utilities      -10.6202  2018
# 28                          Energy      -32.0337  2018
# 29                    Construction      -32.8794  2018
# 30    Consumer Products & Services      -19.9317  2018
# 31  Industrial Products & Services      -17.3715  2018
# 32                        Property      -27.1838  2018
# 33      Transportation & Logistics      -14.6197  2018
# 34                Finance Services        0.1342  2018
# 35                      Plantation      -15.8866  2018
# 36                      Healthcare       15.1658  2019
# 37      Telecommunications & Media       -1.0917  2019
# 38                      Technology      -14.0959  2019
# 39                       Utilities       40.5750  2019
# 40                          Energy       37.8375  2019
# 41                    Construction      -28.1339  2019
# 42    Consumer Products & Services      -14.5380  2019
# 43  Industrial Products & Services       -1.6534  2019
# 44                        Property      -27.1166  2019
# 45      Transportation & Logistics      -26.8603  2019
# 46                Finance Services      -22.1653  2019
# 47                      Plantation      -11.3974  2019
# 48                      Healthcare      100.4283  2020
# 49      Telecommunications & Media      114.1105  2020
# 50                      Technology      169.2363  2020
# 51                       Utilities       39.8938  2020
# 52                          Energy      -31.6030  2020
# 53                    Construction       27.6940  2020
# 54    Consumer Products & Services      107.3162  2020
# 55  Industrial Products & Services       87.8026  2020
# 56                        Property       27.7619  2020
# 57      Transportation & Logistics      193.3906  2020
# 58                Finance Services       30.7502  2020
# 59                      Plantation       43.7428  2020
